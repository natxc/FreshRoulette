# %%
import requests
import base64
import pandas as pd
import psycopg2
from psycopg2 import sql

# %%
def get_kroger_access_token(client_id, client_secret):
    url = 'https://api-ce.kroger.com/v1/connect/oauth2/token'
    
    credentials = f"{client_id}:{client_secret}"
    encoded_credentials = base64.b64encode(credentials.encode('utf-8')).decode('utf-8')
    
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'Basic ' + encoded_credentials
    }

    data = {
        'grant_type': 'client_credentials',
        'scope': 'product.compact'
    }

    response = requests.post(url, headers=headers, data=data)

    if response.status_code == 200:
        return response.json().get('access_token')
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

access_token = get_kroger_access_token(client_id, client_secret)

# %%
def get_kroger_products(access_token, item):
    url = f'https://api-ce.kroger.com/v1/products?filter.term={item}&filter.locationId=01400441'
    
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Cache-Control': 'no-cache'
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None
    
    return data['data']

# Test
item = 'beef'

products_data = get_kroger_products(access_token, item)

products_data
# Out:
# [{'productId': '0001111034567',
#   'upc': '0001111034567',
#   'aisleLocations': [{'bayNumber': '8',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '3',
#     'side': 'R',
#     'shelfNumber': '1',
#     'shelfPositionInBay': '6'}],
#   'brand': 'Kroger',
#   'categories': ['Meat & Seafood', 'Meat & Seafood', 'Natural & Organic'],
#   'description': 'Kroger® Beef Shaved Steak',
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0001111034567'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0001111034567'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0001111034567'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0001111034567'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111034567'}]},
#    {'perspective': 'back',
#     'sizes': [{'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/back/0001111034567'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/back/0001111034567'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/back/0001111034567'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/back/0001111034567'}]}],
#   'items': [{'itemId': '0001111034567',
#     'favorite': False,
#     'fulfillment': {'curbside': False,
#      'delivery': False,
#      'inStore': False,
#      'shipToHome': False},
#     'price': {'regular': 7.99, 'promo': 0},
#     'size': '14 oz',
#     'soldBy': 'UNIT'}],
#   'itemInformation': {'depth': '6.7', 'height': '2.3', 'width': '8.75'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0001111097139',
#   'upc': '0001111097139',
#   'aisleLocations': [{'bayNumber': '6',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '3',
#     'side': 'R',
#     'shelfNumber': '2',
#     'shelfPositionInBay': '1'}],
#   'brand': 'Private Selection',
#   'categories': ['Meat & Seafood', 'Natural & Organic'],
#   'description': 'Private Selection® 80/20 Angus Ground Beef',
#   'images': [{'perspective': 'back',
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/back/0001111097139'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/back/0001111097139'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/back/0001111097139'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/back/0001111097139'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/back/0001111097139'}]},
#    {'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0001111097139'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0001111097139'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0001111097139'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0001111097139'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111097139'}]}],
#   'items': [{'itemId': '0001111097139',
#     'favorite': False,
#     'fulfillment': {'curbside': True,
#      'delivery': True,
#      'inStore': True,
#      'shipToHome': False},
#     'price': {'regular': 6.49, 'promo': 0},
#     'size': '1 lb',
#     'soldBy': 'UNIT'}],
#   'itemInformation': {'depth': '5.65', 'height': '1.75', 'width': '8.05'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0001111097920',
#   'upc': '0001111097920',
#   'aisleLocations': [{'bayNumber': '7',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '1',
#     'side': 'R',
#     'shelfNumber': '1',
#     'shelfPositionInBay': '3'}],
#   'brand': 'Kroger',
#   'categories': ['Meat & Seafood'],
#   'description': 'Kroger® 73/27 Ground Beef Roll',
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0001111097920'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0001111097920'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0001111097920'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0001111097920'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111097920'}]}],
#   'items': [{'itemId': '0001111097920',
#     'favorite': False,
#     'fulfillment': {'curbside': True,
#      'delivery': True,
#      'inStore': True,
#      'shipToHome': False},
#     'price': {'regular': 4.29, 'promo': 0},
#     'size': '1 lb',
#     'soldBy': 'UNIT'}],
#   'itemInformation': {'depth': '2.45', 'height': '2.3', 'width': '7.1'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0001111096920',
#   'upc': '0001111096920',
#   'aisleLocations': [],
#   'brand': 'Kroger',
#   'categories': ['Meat & Seafood', 'Natural & Organic'],
#   'description': 'Kroger® 93/7 Lean Ground Beef',
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0001111096920'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0001111096920'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0001111096920'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0001111096920'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111096920'}]},
#    {'perspective': 'back',
#     'sizes': [{'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/back/0001111096920'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/back/0001111096920'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/back/0001111096920'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/back/0001111096920'}]}],
#   'items': [{'itemId': '0001111096920',
#     'favorite': False,
#     'fulfillment': {'curbside': True,
#      'delivery': True,
#      'inStore': True,
#      'shipToHome': False},
#     'size': '16 oz'}],
#   'itemInformation': {},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0061266931671',
#   'upc': '0061266931671',
#   'aisleLocations': [{'bayNumber': '6',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '4',
#     'side': 'R',
#     'shelfNumber': '4',
#     'shelfPositionInBay': '2'}],
#   'brand': "Laura's Lean Beef",
#   'categories': ['Meat & Seafood', 'Natural & Organic'],
#   'description': "Laura's Lean Beef All Natural 92% Lean Ground Beef",
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0061266931671'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0061266931671'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0061266931671'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0061266931671'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0061266931671'}]}],
#   'items': [{'itemId': '0061266931671',
#     'favorite': False,
#     'fulfillment': {'curbside': False,
#      'delivery': False,
#      'inStore': False,
#      'shipToHome': False},
#     'price': {'regular': 8.99, 'promo': 0},
#     'size': '1 lb',
#     'soldBy': 'UNIT'}],
#   'itemInformation': {'depth': '6.9', 'height': '1.6', 'width': '14.2'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0024184200000',
#   'upc': '0024184200000',
#   'aisleLocations': [{'bayNumber': '8',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '2',
#     'side': 'R',
#     'shelfNumber': '2',
#     'shelfPositionInBay': '2'}],
#   'categories': ['Meat & Seafood', 'Natural & Organic'],
#   'description': 'Beef Choice Chuck Roast',
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0024184200000'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0024184200000'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0024184200000'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0024184200000'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0024184200000'}]}],
#   'items': [{'itemId': '0024184200000',
#     'favorite': False,
#     'fulfillment': {'curbside': False,
#      'delivery': False,
#      'inStore': False,
#      'shipToHome': False},
#     'price': {'regular': 7.99, 'promo': 0, 'regularPerUnitEstimate': 2.28},
#     'size': '1 lb',
#     'soldBy': 'WEIGHT'}],
#   'itemInformation': {'depth': '1.0', 'height': '8.5', 'width': '10.5'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0001111096970',
#   'upc': '0001111096970',
#   'aisleLocations': [{'bayNumber': '6',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '6',
#     'side': 'R',
#     'shelfNumber': '2',
#     'shelfPositionInBay': '2'}],
#   'brand': 'Kroger',
#   'categories': ['Meat & Seafood', 'Natural & Organic'],
#   'description': 'Kroger® 80/20 Ground Beef',
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0001111096970'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0001111096970'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0001111096970'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0001111096970'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111096970'}]}],
#   'items': [{'itemId': '0001111096970',
#     'favorite': False,
#     'fulfillment': {'curbside': True,
#      'delivery': True,
#      'inStore': True,
#      'shipToHome': False},
#     'price': {'regular': 16.49, 'promo': 0},
#     'size': '3 lb',
#     'soldBy': 'UNIT'}],
#   'itemInformation': {'depth': '3.4', 'height': '3.2', 'width': '11.7'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0001111097972',
#   'upc': '0001111097972',
#   'aisleLocations': [{'bayNumber': '5',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '3',
#     'side': 'R',
#     'shelfNumber': '1',
#     'shelfPositionInBay': '1'}],
#   'brand': 'Kroger',
#   'categories': ['Meat & Seafood'],
#   'description': 'Kroger® 80/20 Ground Beef Roll',
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0001111097972'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0001111097972'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0001111097972'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0001111097972'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111097972'}]}],
#   'items': [{'itemId': '0001111097972',
#     'favorite': False,
#     'fulfillment': {'curbside': False,
#      'delivery': False,
#      'inStore': False,
#      'shipToHome': False},
#     'price': {'regular': 14.99, 'promo': 0},
#     'size': '3 lb',
#     'soldBy': 'UNIT'}],
#   'itemInformation': {'depth': '3.45', 'height': '3.1', 'width': '11.6'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0001111096972',
#   'upc': '0001111096972',
#   'aisleLocations': [{'bayNumber': '6',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '8',
#     'side': 'R',
#     'shelfNumber': '3',
#     'shelfPositionInBay': '2'}],
#   'brand': 'Kroger',
#   'categories': ['Meat & Seafood', 'Natural & Organic'],
#   'description': 'Kroger® 80/20 Ground Beef',
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0001111096972'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0001111096972'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0001111096972'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0001111096972'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111096972'}]}],
#   'items': [{'itemId': '0001111096972',
#     'favorite': False,
#     'fulfillment': {'curbside': False,
#      'delivery': False,
#      'inStore': False,
#      'shipToHome': False},
#     'price': {'regular': 5.99, 'promo': 0},
#     'size': '1 lb',
#     'soldBy': 'UNIT'}],
#   'itemInformation': {'depth': '5.7', 'height': '1.75', 'width': '9.35'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}},
#  {'productId': '0001111097971',
#   'upc': '0001111097971',
#   'aisleLocations': [{'bayNumber': '7',
#     'description': 'BACK WALL',
#     'number': '152',
#     'numberOfFacings': '3',
#     'side': 'R',
#     'shelfNumber': '1',
#     'shelfPositionInBay': '4'}],
#   'brand': 'Kroger',
#   'categories': ['Meat & Seafood'],
#   'description': 'Kroger® 80/20 Ground Beef Roll',
#   'images': [{'perspective': 'front',
#     'featured': True,
#     'sizes': [{'size': 'xlarge',
#       'url': 'https://www.kroger.com/product/images/xlarge/front/0001111097971'},
#      {'size': 'large',
#       'url': 'https://www.kroger.com/product/images/large/front/0001111097971'},
#      {'size': 'medium',
#       'url': 'https://www.kroger.com/product/images/medium/front/0001111097971'},
#      {'size': 'small',
#       'url': 'https://www.kroger.com/product/images/small/front/0001111097971'},
#      {'size': 'thumbnail',
#       'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111097971'}]}],
#   'items': [{'itemId': '0001111097971',
#     'favorite': False,
#     'fulfillment': {'curbside': False,
#      'delivery': False,
#      'inStore': False,
#      'shipToHome': False},
#     'price': {'regular': 5.49, 'promo': 0},
#     'size': '1 lb',
#     'soldBy': 'UNIT'}],
#   'itemInformation': {'depth': '2.45', 'height': '2.3', 'width': '7.05'},
#   'temperature': {'indicator': 'Refrigerated', 'heatSensitive': False}}]

# %%
conn = psycopg2.connect(
    dbname=dbname,
    user=user,
    password=password,
    host=host,
    port=port
)

cur = conn.cursor()

table_name = 'ingredients'
query = sql.SQL('select distinct "Ingredient" from {}').format(sql.Identifier(table_name))

# Finding weird anomolies in the names and then updating them
# query = sql.SQL("select distinct {} from {} where {} like %s").format(
#     sql.Identifier("Ingredient"),
#     sql.Identifier(table_name),
#     sql.Identifier("Ingredient")
# )

# pattern = '%0.5%'

# cur.execute(query, (pattern,))

cur.execute(query)

rows = cur.fetchall()

for row in rows:
    ingredient = row[0]
    # Getting the ingredient categories
    kroger_data = get_kroger_products(access_token, ingredient)

    if kroger_data:
        categories = [item for item in set(kroger_data[0]['categories'])]

        print(f"{ingredient} - {categories}")
    else:
        print(f"{ingredient} - Add a new category")

# %%
cur.close()
conn.close()

# %%
# cur = conn.cursor()

# table_name = 'ingredients'
# update_query = sql.SQL('update {} set "Ingredient" = %s where "Ingredient" = %s').format(sql.Identifier(table_name))

# cur.execute(update_query, ('Sabra Classic Hummus', 'Sabra0.5 Classic Hummus'))

# conn.commit()

# cur.close()
# conn.close()
